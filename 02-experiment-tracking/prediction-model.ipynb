# %%
# !python -V
# Out:
# Python 3.12.1

# %%
pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: seaborn in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: six>=1.5 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Obtaining dependency information for mlflow from https://files.pythonhosted.org/packages/0a/24/f488e66c6f667c7468f439d48446b30adafdb81abfcc01262cf3a50267f5/mlflow-3.2.0-py3-none-any.whl.metadata
#   Downloading mlflow-3.2.0-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==3.2.0 (from mlflow)
#   Obtaining dependency information for mlflow-skinny==3.2.0 from https://files.pythonhosted.org/packages/8e/27/d643aff3652b665e2131b982752cd094b9efbd066a412f30d3e3af2e43a4/mlflow_skinny-3.2.0-py3-none-any.whl.metadata
#   Downloading mlflow_skinny-3.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-tracing==3.2.0 (from mlflow)
#   Obtaining dependency information for mlflow-tracing==3.2.0 from https://files.pythonhosted.org/packages/a3/c9/748c70024375001b8840d00eb64c102d22fd3e808c2b4c2f7772dbf452f1/mlflow_tracing-3.2.0-py3-none-any.whl.metadata
#   Downloading mlflow_tracing-3.2.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask<4 (from mlflow)
#   Obtaining dependency information for Flask<4 from https://files.pythonhosted.org/packages/3d/68/9d4508e893976286d2ead7f8f571314af6c2037af34853a30fd769c02e9d/flask-3.1.1-py3-none-any.whl.metadata
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Obtaining dependency information for alembic!=1.10.0,<2 from https://files.pythonhosted.org/packages/c2/62/96b5217b742805236614f05904541000f55422a6060a90d7fd4ce26c172d/alembic-1.16.4-py3-none-any.whl.metadata
#   Using cached alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Obtaining dependency information for docker<8,>=4.0.0 from https://files.pythonhosted.org/packages/e3/26/57c6fb270950d476074c087527a558ccb6f4436657314bfb6cdf484114c4/docker-7.1.0-py3-none-any.whl.metadata
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Obtaining dependency information for graphene<4 from https://files.pythonhosted.org/packages/66/e0/61d8e98007182e6b2aca7cf65904721fb2e4bce0192272ab9cb6f69d8812/graphene-3.4.3-py2.py3-none-any.whl.metadata
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Obtaining dependency information for gunicorn<24 from https://files.pythonhosted.org/packages/cb/7d/6dac2a6e1eba33ee43f318edbed4ff29151a49b5d37f080aad1e6469bca4/gunicorn-23.0.0-py3-none-any.whl.metadata
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: numpy<3 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (2.3.2)
# Requirement already satisfied: pandas<3 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (2.3.1)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (1.7.1)
# Requirement already satisfied: scipy<2 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow) (1.16.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Obtaining dependency information for sqlalchemy<3,>=1.4.0 from https://files.pythonhosted.org/packages/86/00/fcd8daab13a9119d41f3e485a101c29f5d2085bda459154ba354c616bf4e/sqlalchemy-2.0.42-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading sqlalchemy-2.0.42-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for cachetools<7,>=5.0.0 from https://files.pythonhosted.org/packages/00/f0/2ef431fe4141f5e334759d73e81120492b23b2824336883a91ac04ba710b/cachetools-6.1.0-py3-none-any.whl.metadata
#   Using cached cachetools-6.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for click<9,>=7.0 from https://files.pythonhosted.org/packages/85/32/10bb5764d90a8eee674e9dc6f4db6a0ab47c8c4d0d83c27f7c39ac415a4d/click-8.2.1-py3-none-any.whl.metadata
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for cloudpickle<4 from https://files.pythonhosted.org/packages/7e/e8/64c37fadfc2816a7701fa8a6ed8d87327c7d54eacfbfb6edab14a2f2be75/cloudpickle-3.1.1-py3-none-any.whl.metadata
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for databricks-sdk<1,>=0.20.0 from https://files.pythonhosted.org/packages/c7/cd/5fe949ec0b160130066d0ba82b4f499dc494a7405723836ebc37511f6bfc/databricks_sdk-0.62.0-py3-none-any.whl.metadata
#   Downloading databricks_sdk-0.62.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for fastapi<1 from https://files.pythonhosted.org/packages/e5/47/d63c60f59a59467fda0f93f46335c9d18526d7071f025cb5b89d5353ea42/fastapi-0.116.1-py3-none-any.whl.metadata
#   Using cached fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for gitpython<4,>=3.1.9 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for importlib_metadata!=4.7.0,<9,>=3.7.0 from https://files.pythonhosted.org/packages/20/b0/36bd937216ec521246249be3bf9855081de4c5e06a0c9b4219dbeda50373/importlib_metadata-8.7.0-py3-none-any.whl.metadata
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for opentelemetry-api<3,>=1.9.0 from https://files.pythonhosted.org/packages/bb/ee/6b08dde0a022c463b88f55ae81149584b125a42183407dc1045c486cc870/opentelemetry_api-1.36.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for opentelemetry-sdk<3,>=1.9.0 from https://files.pythonhosted.org/packages/0b/59/7bed362ad1137ba5886dac8439e84cd2df6d087be7c09574ece47ae9b22c/opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for protobuf<7,>=3.12.0 from https://files.pythonhosted.org/packages/fa/b1/b59d405d64d31999244643d88c45c8241c58f17cc887e73bcb90602327f8/protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for pydantic<3,>=1.10.8 from https://files.pythonhosted.org/packages/6a/c0/ec2b1c8712ca690e5d61979dee872603e92b8a32f94cc1b72d53beab008a/pydantic-2.11.7-py3-none-any.whl.metadata
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for pyyaml<7,>=5.1 from https://files.pythonhosted.org/packages/b9/2b/614b4752f2e127db5cc206abc23a8c19678e92b23c3db30fc86ab731d3bd/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for requests<3,>=2.17.3 from https://files.pythonhosted.org/packages/7c/e4/56027c4a6b4ae70ca9de302488c5ca95ad4a39e190093d6c1a8ace08341b/requests-2.32.4-py3-none-any.whl.metadata
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for sqlparse<1,>=0.4.0 from https://files.pythonhosted.org/packages/a9/5c/bfd6bd0bf979426d405cc6e71eceb8701b148b16c21d2dc3c261efc61c7b/sqlparse-0.5.3-py3-none-any.whl.metadata
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for typing-extensions<5,>=4.0.0 from https://files.pythonhosted.org/packages/b5/00/d631e67a838026495268c2f6884f3711a15a9a2a96cd244fdaea53b823fb/typing_extensions-4.14.1-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for uvicorn<1 from https://files.pythonhosted.org/packages/d2/e2/dc81b1bd1dcfe91735810265e9d26bc8ec5da45b4c0f6237e286819194c3/uvicorn-0.35.0-py3-none-any.whl.metadata
#   Using cached uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/87/fb/99f81ac72ae23375f22b7afdb7642aba97c00a713c217124420147681a2f/mako-1.3.10-py3-none-any.whl.metadata
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Obtaining dependency information for urllib3>=1.26.0 from https://files.pythonhosted.org/packages/a7/c2/fe1e52489ae3122415c51f387e221dd0773709bad6c6cdaa599e8a2c5185/urllib3-2.5.0-py3-none-any.whl.metadata
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Obtaining dependency information for blinker>=1.9.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Obtaining dependency information for itsdangerous>=2.2.0 from https://files.pythonhosted.org/packages/04/96/92447566d16df59b2a776c0fb82dbc4d9e07cd95062562af01e408583fc4/itsdangerous-2.2.0-py3-none-any.whl.metadata
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask<4->mlflow)
#   Obtaining dependency information for jinja2>=3.1.2 from https://files.pythonhosted.org/packages/62/a1/3d680cbfd5f4b8f15abc1d571870c5fc3e594bb582bc3b64ea099db13e56/jinja2-3.1.6-py3-none-any.whl.metadata
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<4->mlflow)
#   Obtaining dependency information for markupsafe>=2.1.1 from https://files.pythonhosted.org/packages/f3/f0/89e7aadfb3749d0f52234a0c8c7867877876e0a20b60e2188e9850794c17/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Obtaining dependency information for werkzeug>=3.1.0 from https://files.pythonhosted.org/packages/52/24/ab44c871b0f07f491e5d2ad12c9bd7358e527510618cb1b803a88e986db1/werkzeug-3.1.3-py3-none-any.whl.metadata
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Obtaining dependency information for graphql-core<3.3,>=3.1 from https://files.pythonhosted.org/packages/ae/4f/7297663840621022bc73c22d7d9d80dbc78b4db6297f764b545cd5dd462d/graphql_core-3.2.6-py3-none-any.whl.metadata
#   Using cached graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Obtaining dependency information for graphql-relay<3.3,>=3.1 from https://files.pythonhosted.org/packages/74/16/a4cf06adbc711bd364a73ce043b0b08d8fa5aae3df11b6ee4248bcdad2e0/graphql_relay-3.2.0-py3-none-any.whl.metadata
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/19/0d/6660d55f7373b2ff8152401a83e02084956da23ae58cddbfb0b330978fe9/greenlet-3.2.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading greenlet-3.2.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for google-auth~=2.0 from https://files.pythonhosted.org/packages/17/63/b19553b658a1692443c62bd07e5868adaa0ad746a0751ba62c59568cd45b/google_auth-2.40.3-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for starlette<0.48.0,>=0.40.0 from https://files.pythonhosted.org/packages/f7/1f/b876b1f83aef204198a42dc101613fefccb32258e5428b5f9259677864b4/starlette-0.47.2-py3-none-any.whl.metadata
#   Using cached starlette-0.47.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for zipp>=3.20 from https://files.pythonhosted.org/packages/2e/54/647ade08bf0db230bfea292f893923872fd20be6ac6f53b2b936ba839d75/zipp-3.23.0-py3-none-any.whl.metadata
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.57b0 from https://files.pythonhosted.org/packages/05/75/7d591371c6c39c73de5ce5da5a2cc7b72d1d1cd3f8f4638f553c01c37b11/opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for pydantic-core==2.33.2 from https://files.pythonhosted.org/packages/f9/41/4b043778cf9c4285d59742281a769eac371b9e47e35f98ad321349cc5d61/pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/17/69/cd203477f944c353c31bade965f880aa1061fd6bf05ded0726ca845b6ff7/typing_inspection-0.4.1-py3-none-any.whl.metadata
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/8c/73/6ede2ec59bce19b3edf4209d70004253ec5f4e319f9a2e3f2f15601ed5f7/charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/e5/48/1549795ba7742c948d2ad169c1c8cdbae65bc450d6cd753d124b17c8cd32/certifi-2025.8.3-py3-none-any.whl.metadata
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for h11>=0.8 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for cachetools<7,>=5.0.0 from https://files.pythonhosted.org/packages/72/76/20fa66124dbe6be5cafeb312ece67de6b61dd91a0247d1ea13db4ebb33c2/cachetools-5.5.2-py3-none-any.whl.metadata
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for pyasn1-modules>=0.2.1 from https://files.pythonhosted.org/packages/47/8d/d529b5d697919ba8c11ad626e835d4039be708a35b0d22de83a269a6682c/pyasn1_modules-0.4.2-py3-none-any.whl.metadata
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/64/8d/0133e4eb4beed9e425d9a98ed6e081a55d195481b7632472be1af08d2f6b/rsa-4.9.1-py3-none-any.whl.metadata
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for anyio<5,>=3.6.2 from https://files.pythonhosted.org/packages/6f/12/e5e0282d673bb9746bacfb6e2dba8719989d3660cdb2ea79aee9a9651afb/anyio-4.10.0-py3-none-any.whl.metadata
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for sniffio>=1.1 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow)
#   Obtaining dependency information for pyasn1<0.7.0,>=0.6.1 from https://files.pythonhosted.org/packages/c8/f1/d6a797abb14f6283c0ddff96bbdd46937f64122b8c925cab503dd37f8214/pyasn1-0.6.1-py3-none-any.whl.metadata
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading mlflow-3.2.0-py3-none-any.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 34.2 MB/s eta 0:00:00:00:0100:01
# Downloading mlflow_skinny-3.2.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.4 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.2.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.0 MB/s eta 0:00:00
# Using cached alembic-1.16.4-py3-none-any.whl (247 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask-3.1.1-py3-none-any.whl (103 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading sqlalchemy-2.0.42-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 45.4 MB/s eta 0:00:00:00:01
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading databricks_sdk-0.62.0-py3-none-any.whl (681 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.8/681.8 kB 66.9 MB/s eta 0:00:00
# Using cached fastapi-0.116.1-py3-none-any.whl (95 kB)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.2.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (607 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.6/607.6 kB 52.2 MB/s eta 0:00:00
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 18.1 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 32.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 40.7 MB/s eta 0:00:00
# Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 37.2 MB/s eta 0:00:00
# Using cached charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached starlette-0.47.2-py3-none-any.whl (72 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 18.1 MB/s eta 0:00:00
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, urllib3, typing-extensions, sqlparse, sniffio, smmap, pyyaml, pyasn1, protobuf, markupsafe, itsdangerous, idna, h11, gunicorn, greenlet, graphql-core, cloudpickle, click, charset_normalizer, certifi, cachetools, blinker, annotated-types, werkzeug, uvicorn, typing-inspection, sqlalchemy, rsa, requests, pydantic-core, pyasn1-modules, Mako, jinja2, importlib_metadata, graphql-relay, gitdb, anyio, starlette, pydantic, opentelemetry-api, graphene, google-auth, gitpython, Flask, docker, alembic, opentelemetry-semantic-conventions, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
# Successfully installed Flask-3.1.1 Mako-1.3.10 alembic-1.16.4 annotated-types-0.7.0 anyio-4.10.0 blinker-1.9.0 cachetools-5.5.2 certifi-2025.8.3 charset_normalizer-3.4.2 click-8.2.1 cloudpickle-3.1.1 databricks-sdk-0.62.0 docker-7.1.0 fastapi-0.116.1 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.2.4 gunicorn-23.0.0 h11-0.16.0 idna-3.10 importlib_metadata-8.7.0 itsdangerous-2.2.0 jinja2-3.1.6 markupsafe-3.0.2 mlflow-3.2.0 mlflow-skinny-3.2.0 mlflow-tracing-3.2.0 opentelemetry-api-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.7 pydantic-core-2.33.2 pyyaml-6.0.2 requests-2.32.4 rsa-4.9.1 smmap-5.0.2 sniffio-1.3.1 sqlalchemy-2.0.42 sqlparse-0.5.3 starlette-0.47.2 typing-extensions-4.14.1 typing-inspection-0.4.1 urllib3-2.5.0 uvicorn-0.35.0 werkzeug-3.1.3 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import pickle

# %%
import matplotlib.pyplot as plt

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/f3/1b/998312db6d361ded1dd56b457ada371a8d8d77ca2195a7d18fd8a1736f21/scikit_learn-1.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached scikit_learn-1.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from scikit-learn) (2.3.2)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.8.0 from https://files.pythonhosted.org/packages/51/1e/79023ca3bbb13a015d7d2757ecca3b81293c663694c35d6541b4dca53e98/scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/7d/4f/1195bbac8e0c2acc5f740661631d8d750dc38d4a32b23ee5df3cde6f4e0d/joblib-1.5.1-py3-none-any.whl.metadata
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.5 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.2 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Obtaining dependency information for pyarrow from https://files.pythonhosted.org/packages/ad/90/2660332eeb31303c13b653ea566a9918484b6e4d6b9d2d46879a33ab0622/pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata
#   Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 22.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-21.0.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Collecting fastparquet
#   Obtaining dependency information for fastparquet from https://files.pythonhosted.org/packages/e0/2c/b3b3e6ca2e531484289024138cd4709c22512b3fe68066d7f9849da4a76c/fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from fastparquet) (2.3.1)
# Requirement already satisfied: numpy in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from fastparquet) (2.3.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Obtaining dependency information for cramjam>=2.3 from https://files.pythonhosted.org/packages/dc/f0/5c2a5cd5711032f3b191ca50cb786c17689b4a9255f9f768866e6c9f04d9/cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting fsspec (from fastparquet)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/2f/e0/014d5d9d7a4564cf1c40b5039bc882db69fd881111e03ab3657ac0b218e2/fsspec-2025.7.0-py3-none-any.whl.metadata
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /workspaces/Mlops-Zoomcamp-2025/exp-tracking-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Using cached cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0 fsspec-2025.7.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.1

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
from sklearn.metrics import mean_squared_error

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/08/07 15:47:13 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/08/07 15:47:13 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# INFO  [alembic.runtime.migration] Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/08/07 15:47:13 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/workspaces/Mlops-Zoomcamp-2025/02-experiment-tracking/mlruns/1', creation_time=1754581633111, experiment_id='1', last_update_time=1754581633111, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import pyarrow

# %%
import fastparquet

# %%
print(f"PyArrow version: {pyarrow.__version__}, {fastparquet.__version__}")
# Out:
# PyArrow version: 21.0.0, 2024.11.0

# %%
df = pd.read_parquet("./data/green_tripdata_2021-01.parquet", engine='fastparquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50   0.50      0.5        0.00          0.00        NaN
# 1            10.00   0.50      0.5        2.81          0.00        NaN
# 2             6.00   0.50      0.5        1.00          0.00        NaN
# 3             8.00   0.50      0.5        0.00          0.00        NaN
# 4           -52.00   0.00     -0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 76513        56.23   2.75      0.0        0.00          6.12        NaN
# 76514        46.66   0.00      0.0       12.20          6.12        NaN
# 76515        18.95   2.75      0.0        0.00          0.00        NaN
# 76516        48.87   2.75      0.0        0.00          6.12        NaN
# 76517        15.45   2.75      0.0        0.00          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         65.40           NaN        NaN
# 76514                    0.3         65.28           NaN        NaN
# 76515                    0.3         22.00           NaN        NaN
# 76516                    0.3         58.04           NaN        NaN
# 76517                    0.3         18.50           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename, engine='fastparquet')
    df_lpep_pickup_datetime = pd.to_datetime(df["lpep_pickup_datetime"])
    df_lpep_dropoff_datetime = pd.to_datetime(df["lpep_dropoff_datetime"])
    df["duration"] = df_lpep_dropoff_datetime - df_lpep_pickup_datetime
    df["duration"] = df["duration"].apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    categorical = ["PULocationID", "DOLocationID"]
    numerical = ["trip_distance"]
    df[categorical] = df[categorical].astype("str")
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')

# %%
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred)
# Out:
# 60.19766169579813

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
target = "duration"
y_train = df_train[target].values
y_val = df_val[target].values
y_val.shape
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_val)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
rmse

# %%
lasso_model = Lasso(alpha = 0.001)
lasso_model.fit(x_train, y_train)
y_pred = lasso_model.predict(x_val)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# (61921,)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(rmse)
    rmse
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
# Out:
# np.float64(10.499110710357629)

# %%
# Out:
# Lasso(alpha=0.001)

# %%
dv = DictVectorizer()
df_train['PU_DO'] = df_train["PULocationID"] + df_train["DOLocationID"]
df_val['PU_DO'] = df_val["PULocationID"] + df_val["DOLocationID"]
categorical = ["PU_DO"]
numerical = ["trip_distance"]

train_dicts = df_train[categorical + numerical].to_dict(orient="records")
x_train = dv.fit_transform(train_dicts)
val_dicts = df_val[categorical + numerical].to_dict(orient="records")
x_val = dv.transform(val_dicts)

# %%
target = "duration"
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_val)
mse = mean_squared_error(y_val, y_pred)

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(7.787351949801436)

# %%
# Out:
# np.float64(9.240687964649634)

# %%
with open("models/lin_reg.bin", "wb") as f_out:
    pickle.dump((dv, lr), f_out)
