# %%
# !python -V
# Out:
# Python 3.12.1

# %%
pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.1.4)
# Requirement already satisfied: mlflow-skinny==3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: Flask<4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (3.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (1.16.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: numpy<3 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: pandas<3 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (20.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow) (2.0.41)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.60.0)
# Requirement already satisfied: fastapi<1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.35.0)
# Requirement already satisfied: packaging<26 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.31.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.35.0)
# Requirement already satisfied: Mako in /usr/local/python/3.12.1/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.40.3)
# Requirement already satisfied: urllib3>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.47.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/codespace/.local/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/codespace/.local/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.4->mlflow) (0.56b0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/codespace/.local/lib/python3.12/site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/codespace/.local/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.1.4->mlflow) (0.16.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import pickle

# %%
import matplotlib.pyplot as plt

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/python/3.12.1/lib/python3.12/site-packages (20.0.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /usr/local/python/3.12.1/lib/python3.12/site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (2.2.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (2.2.6)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
from sklearn.metrics import mean_squared_error

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/09/04 09:26:38 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/09/04 09:26:38 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# INFO  [alembic.runtime.migration] Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# INFO  [alembic.runtime.migration] Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# INFO  [alembic.runtime.migration] Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# INFO  [alembic.runtime.migration] Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# INFO  [alembic.runtime.migration] Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# INFO  [alembic.runtime.migration] Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# INFO  [alembic.runtime.migration] Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# INFO  [alembic.runtime.migration] Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# INFO  [alembic.runtime.migration] Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# INFO  [alembic.runtime.migration] Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/09/04 09:26:39 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/workspaces/Mlops-Zoomcamp-2025/02-experiment-tracking/mlruns/1', creation_time=1756977999220, experiment_id='1', last_update_time=1756977999220, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import pyarrow

# %%
import fastparquet

# %%
print(f"PyArrow version: {pyarrow.__version__}, {fastparquet.__version__}")
# Out:
# PyArrow version: 20.0.0, 2024.11.0

# %%
df = pd.read_parquet("./data/green_tripdata_2021-01.parquet", engine='fastparquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50   0.50      0.5        0.00          0.00        NaN
# 1            10.00   0.50      0.5        2.81          0.00        NaN
# 2             6.00   0.50      0.5        1.00          0.00        NaN
# 3             8.00   0.50      0.5        0.00          0.00        NaN
# 4           -52.00   0.00     -0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 76513        56.23   2.75      0.0        0.00          6.12        NaN
# 76514        46.66   0.00      0.0       12.20          6.12        NaN
# 76515        18.95   2.75      0.0        0.00          0.00        NaN
# 76516        48.87   2.75      0.0        0.00          6.12        NaN
# 76517        15.45   2.75      0.0        0.00          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         65.40           NaN        NaN
# 76514                    0.3         65.28           NaN        NaN
# 76515                    0.3         22.00           NaN        NaN
# 76516                    0.3         58.04           NaN        NaN
# 76517                    0.3         18.50           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename, engine='fastparquet')
    df_lpep_pickup_datetime = pd.to_datetime(df["lpep_pickup_datetime"])
    df_lpep_dropoff_datetime = pd.to_datetime(df["lpep_dropoff_datetime"])
    df["duration"] = df_lpep_dropoff_datetime - df_lpep_pickup_datetime
    df["duration"] = df["duration"].apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    categorical = ["PULocationID", "DOLocationID"]
    numerical = ["trip_distance"]
    df[categorical] = df[categorical].astype("str")
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')

# %%
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred)
# Out:
# 60.197661679003765

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
target = "duration"
y_train = df_train[target].values
y_val = df_val[target].values
y_val.shape
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(7.758715208009878)

# %%
lasso_model = Lasso(alpha = 0.001)
lasso_model.fit(X_train, y_train)
y_pred = lasso_model.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(9.233436225720547)

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.0001
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    with open('models/lin_reg2.bin', 'wb') as f_out:
        pickle.dump((dv, lr), f_out)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(rmse)
    rmse
    mlflow.log_metric("rmse", rmse)
    print(rmse)

    mlflow.log_artifact(local_path="models/lin_reg2.bin", artifact_path="models_pickle")
# Out:
# 7.616617761096093

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.4)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from xgboost) (2.27.7)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from xgboost) (1.15.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.2.7)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from hyperopt) (2.2.6)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from hyperopt) (1.15.3)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.12/site-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /home/codespace/.local/lib/python3.12/site-packages (from hyperopt) (3.3)
# Requirement already satisfied: future in /usr/local/python/3.12.1/lib/python3.12/site-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: cloudpickle in /usr/local/python/3.12.1/lib/python3.12/site-packages (from hyperopt) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/python/3.12.1/lib/python3.12/site-packages (from hyperopt) (0.10.9.9)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        # mlflow.xgboost.autolog()
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(rmse)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [09:33:15] WARNING: /workspace/src/objective/regression_obj.cu:245: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:11.77730
# [1]	validation-rmse:11.37370
# [2]	validation-rmse:10.99777
# [3]	validation-rmse:10.64825
# [4]	validation-rmse:10.32402
# [5]	validation-rmse:10.02469
# [6]	validation-rmse:9.74504
# [7]	validation-rmse:9.48911
# [8]	validation-rmse:9.25135
# [9]	validation-rmse:9.03406
# [10]	validation-rmse:8.82982
# [11]	validation-rmse:8.64382
# [12]	validation-rmse:8.47437
# [13]	validation-rmse:8.31609
# [14]	validation-rmse:8.16980
# [15]	validation-rmse:8.03755
# [16]	validation-rmse:7.91647
# [17]	validation-rmse:7.80406
# [18]	validation-rmse:7.70292
# [19]	validation-rmse:7.60826
# [20]	validation-rmse:7.52368
# [21]	validation-rmse:7.44729
# [22]	validation-rmse:7.37282
# [23]	validation-rmse:7.30633
# [24]	validation-rmse:7.24597
# [25]	validation-rmse:7.19175
# [26]	validation-rmse:7.14330
# [27]	validation-rmse:7.09657
# [28]	validation-rmse:7.05596
# [29]	validation-rmse:7.01516
# [30]	validation-rmse:6.97938
# [31]	validation-rmse:6.94827
# [32]	validation-rmse:6.91786
# [33]	validation-rmse:6.88853
# [34]	validation-rmse:6.86340
# [35]	validation-rmse:6.83918
# [36]	validation-rmse:6.81859
# [37]	validation-rmse:6.79779
# [38]	validation-rmse:6.77957
# [39]	validation-rmse:6.76434
# [40]	validation-rmse:6.74791
# [41]	validation-rmse:6.73326
# [42]	validation-rmse:6.72031
# [43]	validation-rmse:6.70905
# [44]	validation-rmse:6.69651
# [45]	validation-rmse:6.68647
# [46]	validation-rmse:6.67475
# [47]	validation-rmse:6.66553
# [48]	validation-rmse:6.65699
# [49]	validation-rmse:6.64949
# [50]	validation-rmse:6.64170
# [51]	validation-rmse:6.63337
# [52]	validation-rmse:6.62679
# [53]	validation-rmse:6.62017
# [54]	validation-rmse:6.61281
# [55]	validation-rmse:6.60884
# [56]	validation-rmse:6.60373
# [57]	validation-rmse:6.59848
# [58]	validation-rmse:6.59421
# [59]	validation-rmse:6.58955
# [60]	validation-rmse:6.58508
# [61]	validation-rmse:6.58141
# [62]	validation-rmse:6.57853
# [63]	validation-rmse:6.57479
# [64]	validation-rmse:6.57196
# [65]	validation-rmse:6.56863
# [66]	validation-rmse:6.56537
# [67]	validation-rmse:6.56338
# [68]	validation-rmse:6.56107
# [69]	validation-rmse:6.55882
# [70]	validation-rmse:6.55699
# [71]	validation-rmse:6.55477
# [72]	validation-rmse:6.55228
# [73]	validation-rmse:6.55039
# [74]	validation-rmse:6.54859
# [75]	validation-rmse:6.54690
# [76]	validation-rmse:6.54506
# [77]	validation-rmse:6.54366
# [78]	validation-rmse:6.54247
# [79]	validation-rmse:6.54103
# [80]	validation-rmse:6.53990
# [81]	validation-rmse:6.53827
# [82]	validation-rmse:6.53713
# [83]	validation-rmse:6.53567
# [84]	validation-rmse:6.53452
# [85]	validation-rmse:6.53300
# [86]	validation-rmse:6.53153
# [87]	validation-rmse:6.53022
# [88]	validation-rmse:6.52918
# [89]	validation-rmse:6.52829
# [90]	validation-rmse:6.52690
# [91]	validation-rmse:6.52617
# [92]	validation-rmse:6.52542
# [93]	validation-rmse:6.52448
# [94]	validation-rmse:6.52376
# [95]	validation-rmse:6.52305
# [96]	validation-rmse:6.52222
# [97]	validation-rmse:6.52142
# [98]	validation-rmse:6.52084
# [99]	validation-rmse:6.52007
# [100]	validation-rmse:6.51924
# [101]	validation-rmse:6.51832
# [102]	validation-rmse:6.51754
# [103]	validation-rmse:6.51718
# [104]	validation-rmse:6.51638
# [105]	validation-rmse:6.51568
# [106]	validation-rmse:6.51515
# [107]	validation-rmse:6.51474
# [108]	validation-rmse:6.51410
# [109]	validation-rmse:6.51349
# [110]	validation-rmse:6.51303
# [111]	validation-rmse:6.51221
# [112]	validation-rmse:6.51133
# [113]	validation-rmse:6.51046
# [114]	validation-rmse:6.50997
# [115]	validation-rmse:6.50938
# [116]	validation-rmse:6.50891
# [117]	validation-rmse:6.50836
# [118]	validation-rmse:6.50777
# [119]	validation-rmse:6.50717
# [120]	validation-rmse:6.50643
# [121]	validation-rmse:6.50601
# [122]	validation-rmse:6.50562
# [123]	validation-rmse:6.50525
# [124]	validation-rmse:6.50476
# [125]	validation-rmse:6.50409
# [126]	validation-rmse:6.50380
# [127]	validation-rmse:6.50316
# [128]	validation-rmse:6.50249
# [129]	validation-rmse:6.50167
# [130]	validation-rmse:6.50133
# [131]	validation-rmse:6.50076
# [132]	validation-rmse:6.50039
# [133]	validation-rmse:6.49995
# [134]	validation-rmse:6.49983
# [135]	validation-rmse:6.49906
# [136]	validation-rmse:6.49861
# [137]	validation-rmse:6.49820
# [138]	validation-rmse:6.49786
# [139]	validation-rmse:6.49759
# [140]	validation-rmse:6.49710
# [141]	validation-rmse:6.49674
# [142]	validation-rmse:6.49642
# [143]	validation-rmse:6.49621
# [144]	validation-rmse:6.49580
# [145]	validation-rmse:6.49535
# [146]	validation-rmse:6.49500
# [147]	validation-rmse:6.49423
# [148]	validation-rmse:6.49385
# [149]	validation-rmse:6.49332
# [150]	validation-rmse:6.49290
# [151]	validation-rmse:6.49257
# [152]	validation-rmse:6.49221
# [153]	validation-rmse:6.49195
# [154]	validation-rmse:6.49174
# [155]	validation-rmse:6.49169
# [156]	validation-rmse:6.49153
# [157]	validation-rmse:6.49113
# [158]	validation-rmse:6.49068
# [159]	validation-rmse:6.49046
# [160]	validation-rmse:6.49026
# [161]	validation-rmse:6.49012
# [162]	validation-rmse:6.48947
# [163]	validation-rmse:6.48902
# [164]	validation-rmse:6.48874
# [165]	validation-rmse:6.48846
# [166]	validation-rmse:6.48821
# [167]	validation-rmse:6.48782
# [168]	validation-rmse:6.48760
# [169]	validation-rmse:6.48736
# [170]	validation-rmse:6.48704
# [171]	validation-rmse:6.48683
# [172]	validation-rmse:6.48629
# [173]	validation-rmse:6.48601
# [174]	validation-rmse:6.48565
# [175]	validation-rmse:6.48522
# [176]	validation-rmse:6.48496
# [177]	validation-rmse:6.48462
# [178]	validation-rmse:6.48430
# [179]	validation-rmse:6.48375
# [180]	validation-rmse:6.48352
# [181]	validation-rmse:6.48327
# [182]	validation-rmse:6.48306
# [183]	validation-rmse:6.48291
# [184]	validation-rmse:6.48266
# [185]	validation-rmse:6.48237
# [186]	validation-rmse:6.48229
# [187]	validation-rmse:6.48216
# [188]	validation-rmse:6.48196
# [189]	validation-rmse:6.48172
# [190]	validation-rmse:6.48155
# [191]	validation-rmse:6.48080
# [192]	validation-rmse:6.48062
# [193]	validation-rmse:6.48036
# [194]	validation-rmse:6.47937
# [195]	validation-rmse:6.47895
# [196]	validation-rmse:6.47882
# [197]	validation-rmse:6.47856
# [198]	validation-rmse:6.47842
# [199]	validation-rmse:6.47822
# [200]	validation-rmse:6.47806
# [201]	validation-rmse:6.47768
# [202]	validation-rmse:6.47748
# [203]	validation-rmse:6.47720
# [204]	validation-rmse:6.47687
# [205]	validation-rmse:6.47682
# [206]	validation-rmse:6.47637
# [207]	validation-rmse:6.47616
# [208]	validation-rmse:6.47589
# [209]	validation-rmse:6.47570
# [210]	validation-rmse:6.47515
# [211]	validation-rmse:6.47490
# [212]	validation-rmse:6.47468
# [213]	validation-rmse:6.47452
# [214]	validation-rmse:6.47433
# [215]	validation-rmse:6.47404
# [216]	validation-rmse:6.47380
# [217]	validation-rmse:6.47352
# [218]	validation-rmse:6.47338
# [219]	validation-rmse:6.47319
# [220]	validation-rmse:6.47304
# [221]	validation-rmse:6.47281
# [222]	validation-rmse:6.47262
# [223]	validation-rmse:6.47245
# [224]	validation-rmse:6.47243
# [225]	validation-rmse:6.47232
# [226]	validation-rmse:6.47214
# [227]	validation-rmse:6.47192
# [228]	validation-rmse:6.47171
# [229]	validation-rmse:6.47142
# [230]	validation-rmse:6.47124
# [231]	validation-rmse:6.47106
# [232]	validation-rmse:6.47076
# [233]	validation-rmse:6.47047
# [234]	validation-rmse:6.47021
# [235]	validation-rmse:6.47011
# [236]	validation-rmse:6.46981
# [237]	validation-rmse:6.46968
# [238]	validation-rmse:6.46946
# [239]	validation-rmse:6.46931
# [240]	validation-rmse:6.46927
# [241]	validation-rmse:6.46900
# [242]	validation-rmse:6.46883
# [243]	validation-rmse:6.46871
# [244]	validation-rmse:6.46843
# [245]	validation-rmse:6.46834
# [246]	validation-rmse:6.46802
# [247]	validation-rmse:6.46770
# [248]	validation-rmse:6.46742
# [249]	validation-rmse:6.46721
# [250]	validation-rmse:6.46698
# [251]	validation-rmse:6.46689
# [252]	validation-rmse:6.46676
# [253]	validation-rmse:6.46647
# [254]	validation-rmse:6.46627
# [255]	validation-rmse:6.46580
# [256]	validation-rmse:6.46571
# [257]	validation-rmse:6.46557
# [258]	validation-rmse:6.46524
# [259]	validation-rmse:6.46510
# [260]	validation-rmse:6.46505
# [261]	validation-rmse:6.46457
# [262]	validation-rmse:6.46431
# [263]	validation-rmse:6.46406
# [264]	validation-rmse:6.46390
# [265]	validation-rmse:6.46379
# [266]	validation-rmse:6.46359
# [267]	validation-rmse:6.46342
# [268]	validation-rmse:6.46312
# [269]	validation-rmse:6.46308
# [270]	validation-rmse:6.46291
# [271]	validation-rmse:6.46282
# [272]	validation-rmse:6.46274
# [273]	validation-rmse:6.46270
# [274]	validation-rmse:6.46250
# [275]	validation-rmse:6.46235
# [276]	validation-rmse:6.46227
# [277]	validation-rmse:6.46147
# [278]	validation-rmse:6.46123
# [279]	validation-rmse:6.46099
# [280]	validation-rmse:6.46090
# [281]	validation-rmse:6.46068
# [282]	validation-rmse:6.46042
# [283]	validation-rmse:6.46020
# [284]	validation-rmse:6.45999
# [285]	validation-rmse:6.45991
# [286]	validation-rmse:6.45968
# [287]	validation-rmse:6.45954
# [288]	validation-rmse:6.45943
# [289]	validation-rmse:6.45931
# [290]	validation-rmse:6.45926
# [291]	validation-rmse:6.45904
# [292]	validation-rmse:6.45888
# [293]	validation-rmse:6.45862
# [294]	validation-rmse:6.45853
# [295]	validation-rmse:6.45842
# [296]	validation-rmse:6.45827
# [297]	validation-rmse:6.45810
# [298]	validation-rmse:6.45771
# [299]	validation-rmse:6.45767
# [300]	validation-rmse:6.45739
# [301]	validation-rmse:6.45746
# [302]	validation-rmse:6.45729
# [303]	validation-rmse:6.45715
# [304]	validation-rmse:6.45704
# [305]	validation-rmse:6.45666
# [306]	validation-rmse:6.45650
# [307]	validation-rmse:6.45623
# [308]	validation-rmse:6.45606
# [309]	validation-rmse:6.45591
# [310]	validation-rmse:6.45573
# [311]	validation-rmse:6.45572
# [312]	validation-rmse:6.45556
# [313]	validation-rmse:6.45533
# [314]	validation-rmse:6.45521
# [315]	validation-rmse:6.45504
# [316]	validation-rmse:6.45496
# [317]	validation-rmse:6.45479
# [318]	validation-rmse:6.45467
# [319]	validation-rmse:6.45454
# [320]	validation-rmse:6.45436
# [321]	validation-rmse:6.45417
# [322]	validation-rmse:6.45399
# [323]	validation-rmse:6.45387
# [324]	validation-rmse:6.45377
# [325]	validation-rmse:6.45384
# [326]	validation-rmse:6.45340
# [327]	validation-rmse:6.45307
# [328]	validation-rmse:6.45296
# [329]	validation-rmse:6.45289
# [330]	validation-rmse:6.45286
# [331]	validation-rmse:6.45279
# [332]	validation-rmse:6.45260
# [333]	validation-rmse:6.45237
# [334]	validation-rmse:6.45220
# [335]	validation-rmse:6.45213
# [336]	validation-rmse:6.45220
# [337]	validation-rmse:6.45205
# [338]	validation-rmse:6.45179
# [339]	validation-rmse:6.45161
# [340]	validation-rmse:6.45152
# [341]	validation-rmse:6.45131
# [342]	validation-rmse:6.45121
# [343]	validation-rmse:6.45109
# [344]	validation-rmse:6.45090
# [345]	validation-rmse:6.45072
# [346]	validation-rmse:6.45063
# [347]	validation-rmse:6.45065
# [348]	validation-rmse:6.45044
# [349]	validation-rmse:6.45040
# [350]	validation-rmse:6.45024
# [351]	validation-rmse:6.45004
# [352]	validation-rmse:6.44976
# [353]	validation-rmse:6.44958
# [354]	validation-rmse:6.44945
# [355]	validation-rmse:6.44941
# [356]	validation-rmse:6.44928
# [357]	validation-rmse:6.44915
# [358]	validation-rmse:6.44903
# [359]	validation-rmse:6.44873
# [360]	validation-rmse:6.44860
# [361]	validation-rmse:6.44854
# [362]	validation-rmse:6.44828
# [363]	validation-rmse:6.44812
# [364]	validation-rmse:6.44780
# [365]	validation-rmse:6.44771
# [366]	validation-rmse:6.44766
# [367]	validation-rmse:6.44755
# [368]	validation-rmse:6.44743
# [369]	validation-rmse:6.44728
# [370]	validation-rmse:6.44713
# [371]	validation-rmse:6.44684
# [372]	validation-rmse:6.44664
# [373]	validation-rmse:6.44646
# [374]	validation-rmse:6.44646
# [375]	validation-rmse:6.44639
# [376]	validation-rmse:6.44633
# [377]	validation-rmse:6.44620
# [378]	validation-rmse:6.44607
# [379]	validation-rmse:6.44600
# [380]	validation-rmse:6.44617
# [381]	validation-rmse:6.44565
# [382]	validation-rmse:6.44545
# [383]	validation-rmse:6.44531
# [384]	validation-rmse:6.44525
# [385]	validation-rmse:6.44517
# [386]	validation-rmse:6.44507
# [387]	validation-rmse:6.44487
# [388]	validation-rmse:6.44476
# [389]	validation-rmse:6.44468
# [390]	validation-rmse:6.44469
# [391]	validation-rmse:6.44454
# [392]	validation-rmse:6.44431
# [393]	validation-rmse:6.44417
# [394]	validation-rmse:6.44414
# [395]	validation-rmse:6.44401
# [396]	validation-rmse:6.44409
# [397]	validation-rmse:6.44425
# [398]	validation-rmse:6.44424
# [399]	validation-rmse:6.44417
# [400]	validation-rmse:6.44415
# [401]	validation-rmse:6.44409
# [402]	validation-rmse:6.44398
# [403]	validation-rmse:6.44383
# [404]	validation-rmse:6.44370
# [405]	validation-rmse:6.44361
# [406]	validation-rmse:6.44340
# [407]	validation-rmse:6.44324
# [408]	validation-rmse:6.44307
# [409]	validation-rmse:6.44291
# [410]	validation-rmse:6.44271
# [411]	validation-rmse:6.44247
# [412]	validation-rmse:6.44247
# [413]	validation-rmse:6.44222
# [414]	validation-rmse:6.44224
# [415]	validation-rmse:6.44216
# [416]	validation-rmse:6.44208
# [417]	validation-rmse:6.44196
# [418]	validation-rmse:6.44185
# [419]	validation-rmse:6.44157
# [420]	validation-rmse:6.44139
# [421]	validation-rmse:6.44131
# [422]	validation-rmse:6.44112
# [423]	validation-rmse:6.44103
# [424]	validation-rmse:6.44078
# [425]	validation-rmse:6.44067
# [426]	validation-rmse:6.44050
# [427]	validation-rmse:6.44040
# [428]	validation-rmse:6.44036
# [429]	validation-rmse:6.44022
# [430]	validation-rmse:6.44005
# [431]	validation-rmse:6.43994
# [432]	validation-rmse:6.43984
# [433]	validation-rmse:6.43964
# [434]	validation-rmse:6.43951
# [435]	validation-rmse:6.43945
# [436]	validation-rmse:6.43934
# [437]	validation-rmse:6.43928
# [438]	validation-rmse:6.43918
# [439]	validation-rmse:6.43927
# [440]	validation-rmse:6.43900
# [441]	validation-rmse:6.43891
# [442]	validation-rmse:6.43879
# [443]	validation-rmse:6.43870
# [444]	validation-rmse:6.43872
# [445]	validation-rmse:6.43861
# [446]	validation-rmse:6.43852
# [447]	validation-rmse:6.43840
# [448]	validation-rmse:6.43822
# [449]	validation-rmse:6.43821
# [450]	validation-rmse:6.43812
# [451]	validation-rmse:6.43793
# [452]	validation-rmse:6.43768
# [453]	validation-rmse:6.43765
# [454]	validation-rmse:6.43766
# [455]	validation-rmse:6.43755
# [456]	validation-rmse:6.43733
# [457]	validation-rmse:6.43721
# [458]	validation-rmse:6.43715
# [459]	validation-rmse:6.43711
# [460]	validation-rmse:6.43712
# [461]	validation-rmse:6.43696
# [462]	validation-rmse:6.43672
# [463]	validation-rmse:6.43659
# [464]	validation-rmse:6.43665
# [465]	validation-rmse:6.43658
# [466]	validation-rmse:6.43638
# [467]	validation-rmse:6.43627
# [468]	validation-rmse:6.43614
# [469]	validation-rmse:6.43606
# [470]	validation-rmse:6.43595
# [471]	validation-rmse:6.43582
# [472]	validation-rmse:6.43575
# [473]	validation-rmse:6.43559
# [474]	validation-rmse:6.43553
# [475]	validation-rmse:6.43540
# [476]	validation-rmse:6.43522
# [477]	validation-rmse:6.43517
# [478]	validation-rmse:6.43499
# [479]	validation-rmse:6.43488
# [480]	validation-rmse:6.43491
# [481]	validation-rmse:6.43480
# [482]	validation-rmse:6.43476
# [483]	validation-rmse:6.43461
# [484]	validation-rmse:6.43465
# [485]	validation-rmse:6.43450
# [486]	validation-rmse:6.43439
# [487]	validation-rmse:6.43424
# [488]	validation-rmse:6.43408
# [489]	validation-rmse:6.43404
# [490]	validation-rmse:6.43394
# [491]	validation-rmse:6.43377
# [492]	validation-rmse:6.43366
# [493]	validation-rmse:6.43357
# [494]	validation-rmse:6.43340
# [495]	validation-rmse:6.43333
# [496]	validation-rmse:6.43320
# [497]	validation-rmse:6.43299
# [498]	validation-rmse:6.43296
# [499]	validation-rmse:6.43277
# [500]	validation-rmse:6.43272
# [501]	validation-rmse:6.43278
# [502]	validation-rmse:6.43262
# [503]	validation-rmse:6.43250
# [504]	validation-rmse:6.43237
# [505]	validation-rmse:6.43227
# [506]	validation-rmse:6.43217
# [507]	validation-rmse:6.43208
# [508]	validation-rmse:6.43207
# [509]	validation-rmse:6.43207
# [510]	validation-rmse:6.43203
# [511]	validation-rmse:6.43193
# [512]	validation-rmse:6.43184
# [513]	validation-rmse:6.43183
# [514]	validation-rmse:6.43169
# [515]	validation-rmse:6.43178
# [516]	validation-rmse:6.43173
# [517]	validation-rmse:6.43159
# [518]	validation-rmse:6.43139
# [519]	validation-rmse:6.43136
# [520]	validation-rmse:6.43129
# [521]	validation-rmse:6.43136
# [522]	validation-rmse:6.43123
# [523]	validation-rmse:6.43109
# [524]	validation-rmse:6.43108
# [525]	validation-rmse:6.43099
# [526]	validation-rmse:6.43097
# [527]	validation-rmse:6.43083
# [528]	validation-rmse:6.43069
# [529]	validation-rmse:6.43053
# [530]	validation-rmse:6.43046
# [531]	validation-rmse:6.43035
# [532]	validation-rmse:6.43032
# [533]	validation-rmse:6.43028
# [534]	validation-rmse:6.43019
# [535]	validation-rmse:6.42999
# [536]	validation-rmse:6.42996
# [537]	validation-rmse:6.42999
# [538]	validation-rmse:6.42993
# [539]	validation-rmse:6.42980
# [540]	validation-rmse:6.42977
# [541]	validation-rmse:6.42968
# [542]	validation-rmse:6.42983
# [543]	validation-rmse:6.42926
# [544]	validation-rmse:6.42934
# [545]	validation-rmse:6.42921
# [546]	validation-rmse:6.42913
# [547]	validation-rmse:6.42908
# [548]	validation-rmse:6.42897
# [549]	validation-rmse:6.42887
# [550]	validation-rmse:6.42867
# [551]	validation-rmse:6.42850
# [552]	validation-rmse:6.42851
# [553]	validation-rmse:6.42834
# [554]	validation-rmse:6.42830
# [555]	validation-rmse:6.42832
# [556]	validation-rmse:6.42816
# [557]	validation-rmse:6.42813
# [558]	validation-rmse:6.42812
# [559]	validation-rmse:6.42802
# [560]	validation-rmse:6.42795
# [561]	validation-rmse:6.42783
# [562]	validation-rmse:6.42772
# [563]	validation-rmse:6.42773
# [564]	validation-rmse:6.42748
# [565]	validation-rmse:6.42746
# [566]	validation-rmse:6.42732
# [567]	validation-rmse:6.42718
# [568]	validation-rmse:6.42712
# [569]	validation-rmse:6.42705
# [570]	validation-rmse:6.42698
# [571]	validation-rmse:6.42683
# [572]	validation-rmse:6.42675
# [573]	validation-rmse:6.42663
# [574]	validation-rmse:6.42655
# [575]	validation-rmse:6.42657
# [576]	validation-rmse:6.42653
# [577]	validation-rmse:6.42645
# [578]	validation-rmse:6.42632
# [579]	validation-rmse:6.42623
# [580]	validation-rmse:6.42612
# [581]	validation-rmse:6.42613
# [582]	validation-rmse:6.42604
# [583]	validation-rmse:6.42597
# [584]	validation-rmse:6.42588
# [585]	validation-rmse:6.42581
# [586]	validation-rmse:6.42575
# [587]	validation-rmse:6.42572
# [588]	validation-rmse:6.42576
# [589]	validation-rmse:6.42570
# [590]	validation-rmse:6.42575
# [591]	validation-rmse:6.42563
# [592]	validation-rmse:6.42561
# [593]	validation-rmse:6.42562
# [594]	validation-rmse:6.42569
# [595]	validation-rmse:6.42564
# [596]	validation-rmse:6.42554
# [597]	validation-rmse:6.42538
# [598]	validation-rmse:6.42534
# [599]	validation-rmse:6.42534
# [600]	validation-rmse:6.42526
# [601]	validation-rmse:6.42523
# [602]	validation-rmse:6.42502
# [603]	validation-rmse:6.42482
# [604]	validation-rmse:6.42476
# [605]	validation-rmse:6.42489
# [606]	validation-rmse:6.42491
# [607]	validation-rmse:6.42485
# [608]	validation-rmse:6.42482
# [609]	validation-rmse:6.42470
# [610]	validation-rmse:6.42439
# [611]	validation-rmse:6.42433
# [612]	validation-rmse:6.42443
# [613]	validation-rmse:6.42449
# [614]	validation-rmse:6.42444
# [615]	validation-rmse:6.42445
# [616]	validation-rmse:6.42458
# [617]	validation-rmse:6.42452
# [618]	validation-rmse:6.42429
# [619]	validation-rmse:6.42423
# [620]	validation-rmse:6.42417
# [621]	validation-rmse:6.42411
# [622]	validation-rmse:6.42404
# [623]	validation-rmse:6.42399
# [624]	validation-rmse:6.42389
# [625]	validation-rmse:6.42380
# [626]	validation-rmse:6.42385
# [627]	validation-rmse:6.42383
# [628]	validation-rmse:6.42381
# [629]	validation-rmse:6.42367
# [630]	validation-rmse:6.42359
# [631]	validation-rmse:6.42370
# [632]	validation-rmse:6.42383
# [633]	validation-rmse:6.42365
# [634]	validation-rmse:6.42350
# [635]	validation-rmse:6.42349
# [636]	validation-rmse:6.42336
# [637]	validation-rmse:6.42328
# [638]	validation-rmse:6.42326
# [639]	validation-rmse:6.42315
# [640]	validation-rmse:6.42312
# [641]	validation-rmse:6.42298
# [642]	validation-rmse:6.42300
# [643]	validation-rmse:6.42293
# [644]	validation-rmse:6.42287
# [645]	validation-rmse:6.42281
# [646]	validation-rmse:6.42271
# [647]	validation-rmse:6.42268
# [648]	validation-rmse:6.42264
# [649]	validation-rmse:6.42254
# [650]	validation-rmse:6.42264
# [651]	validation-rmse:6.42255
# [652]	validation-rmse:6.42255
# [653]	validation-rmse:6.42247
# [654]	validation-rmse:6.42242
# [655]	validation-rmse:6.42233
# [656]	validation-rmse:6.42224
# [657]	validation-rmse:6.42220
# [658]	validation-rmse:6.42222
# [659]	validation-rmse:6.42222
# [660]	validation-rmse:6.42205
# [661]	validation-rmse:6.42203
# [662]	validation-rmse:6.42193
# [663]	validation-rmse:6.42185
# [664]	validation-rmse:6.42184
# [665]	validation-rmse:6.42178
# [666]	validation-rmse:6.42181
# [667]	validation-rmse:6.42180
# [668]	validation-rmse:6.42169
# [669]	validation-rmse:6.42167
# [670]	validation-rmse:6.42156
# [671]	validation-rmse:6.42155
# [672]	validation-rmse:6.42142
# [673]	validation-rmse:6.42145
# [674]	validation-rmse:6.42142
# [675]	validation-rmse:6.42139
# [676]	validation-rmse:6.42131
# [677]	validation-rmse:6.42123
# [678]	validation-rmse:6.42127
# [679]	validation-rmse:6.42136
# [680]	validation-rmse:6.42141
# [681]	validation-rmse:6.42142
# [682]	validation-rmse:6.42134
# [683]	validation-rmse:6.42141
# [684]	validation-rmse:6.42128
# [685]	validation-rmse:6.42109
# [686]	validation-rmse:6.42094
# [687]	validation-rmse:6.42095
# [688]	validation-rmse:6.42087
# [689]	validation-rmse:6.42086
# [690]	validation-rmse:6.42076
# [691]	validation-rmse:6.42068
# [692]	validation-rmse:6.42059
# [693]	validation-rmse:6.42045
# [694]	validation-rmse:6.42040
# [695]	validation-rmse:6.42041
# [696]	validation-rmse:6.42052
# [697]	validation-rmse:6.42046
# [698]	validation-rmse:6.42048
# [699]	validation-rmse:6.42040
# [700]	validation-rmse:6.42033
# [701]	validation-rmse:6.42021
# [702]	validation-rmse:6.42011
# [703]	validation-rmse:6.42008
# [704]	validation-rmse:6.42005
# [705]	validation-rmse:6.41988
# [706]	validation-rmse:6.41982
# [707]	validation-rmse:6.41976
# [708]	validation-rmse:6.41994
# [709]	validation-rmse:6.41960
# [710]	validation-rmse:6.41957
# [711]	validation-rmse:6.41945
# [712]	validation-rmse:6.41939
# [713]	validation-rmse:6.41927
# [714]	validation-rmse:6.41928
# [715]	validation-rmse:6.41925
# [716]	validation-rmse:6.41923
# [717]	validation-rmse:6.41919
# [718]	validation-rmse:6.41909
# [719]	validation-rmse:6.41894
# [720]	validation-rmse:6.41899
# [721]	validation-rmse:6.41893
# [722]	validation-rmse:6.41878
# [723]	validation-rmse:6.41875
# [724]	validation-rmse:6.41855
# [725]	validation-rmse:6.41844
# [726]	validation-rmse:6.41847
# [727]	validation-rmse:6.41842
# [728]	validation-rmse:6.41855
# [729]	validation-rmse:6.41851
# [730]	validation-rmse:6.41853
# [731]	validation-rmse:6.41844
# [732]	validation-rmse:6.41847
# [733]	validation-rmse:6.41846
# [734]	validation-rmse:6.41844
# [735]	validation-rmse:6.41845
# [736]	validation-rmse:6.41841
# [737]	validation-rmse:6.41841
# [738]	validation-rmse:6.41835
# [739]	validation-rmse:6.41825
# [740]	validation-rmse:6.41812
# [741]	validation-rmse:6.41803
# [742]	validation-rmse:6.41807
# [743]	validation-rmse:6.41806
# [744]	validation-rmse:6.41802
# [745]	validation-rmse:6.41796
# [746]	validation-rmse:6.41792
# [747]	validation-rmse:6.41787
# [748]	validation-rmse:6.41781
# [749]	validation-rmse:6.41780
# [750]	validation-rmse:6.41771
# [751]	validation-rmse:6.41768
# [752]	validation-rmse:6.41765
# [753]	validation-rmse:6.41762
# [754]	validation-rmse:6.41762
# [755]	validation-rmse:6.41750
# [756]	validation-rmse:6.41760
# [757]	validation-rmse:6.41762
# [758]	validation-rmse:6.41752
# [759]	validation-rmse:6.41743
# [760]	validation-rmse:6.41728
# [761]	validation-rmse:6.41730
# [762]	validation-rmse:6.41735
# [763]	validation-rmse:6.41726
# [764]	validation-rmse:6.41732
# [765]	validation-rmse:6.41743
# [766]	validation-rmse:6.41747
# [767]	validation-rmse:6.41725
# [768]	validation-rmse:6.41722
# [769]	validation-rmse:6.41715
# [770]	validation-rmse:6.41710
# [771]	validation-rmse:6.41718
# [772]	validation-rmse:6.41736
# [773]	validation-rmse:6.41734
# [774]	validation-rmse:6.41723
# [775]	validation-rmse:6.41710
# [776]	validation-rmse:6.41705
# [777]	validation-rmse:6.41696
# [778]	validation-rmse:6.41681
# [779]	validation-rmse:6.41680
# [780]	validation-rmse:6.41675
# [781]	validation-rmse:6.41669
# [782]	validation-rmse:6.41657
# [783]	validation-rmse:6.41649
# [784]	validation-rmse:6.41644
# [785]	validation-rmse:6.41637
# [786]	validation-rmse:6.41634
# [787]	validation-rmse:6.41630
# [788]	validation-rmse:6.41629
# [789]	validation-rmse:6.41618
# [790]	validation-rmse:6.41649
# [791]	validation-rmse:6.41647
# [792]	validation-rmse:6.41699
# [793]	validation-rmse:6.41652
# [794]	validation-rmse:6.41646
# [795]	validation-rmse:6.41642
# [796]	validation-rmse:6.41639
# [797]	validation-rmse:6.41630
# [798]	validation-rmse:6.41633
# [799]	validation-rmse:6.41627
# [800]	validation-rmse:6.41626
# [801]	validation-rmse:6.41621
# [802]	validation-rmse:6.41607
# [803]	validation-rmse:6.41605
# [804]	validation-rmse:6.41597
# [805]	validation-rmse:6.41597
# [806]	validation-rmse:6.41589
# [807]	validation-rmse:6.41586
# [808]	validation-rmse:6.41582
# [809]	validation-rmse:6.41582
# [810]	validation-rmse:6.41575
# [811]	validation-rmse:6.41559
# [812]	validation-rmse:6.41553
# [813]	validation-rmse:6.41552
# [814]	validation-rmse:6.41545
# [815]	validation-rmse:6.41541
# [816]	validation-rmse:6.41535
# [817]	validation-rmse:6.41536
# [818]	validation-rmse:6.41546
# [819]	validation-rmse:6.41548
# [820]	validation-rmse:6.41546
# [821]	validation-rmse:6.41549
# [822]	validation-rmse:6.41546
# [823]	validation-rmse:6.41540
# [824]	validation-rmse:6.41540
# [825]	validation-rmse:6.41533
# [826]	validation-rmse:6.41534
# [827]	validation-rmse:6.41525
# [828]	validation-rmse:6.41523
# [829]	validation-rmse:6.41516
# [830]	validation-rmse:6.41513
# [831]	validation-rmse:6.41508
# [832]	validation-rmse:6.41505
# [833]	validation-rmse:6.41512
# [834]	validation-rmse:6.41510
# [835]	validation-rmse:6.41505
# [836]	validation-rmse:6.41503
# [837]	validation-rmse:6.41505
# [838]	validation-rmse:6.41498
# [839]	validation-rmse:6.41494
# [840]	validation-rmse:6.41505
# [841]	validation-rmse:6.41508
# [842]	validation-rmse:6.41510
# [843]	validation-rmse:6.41514
# [844]	validation-rmse:6.41509
# [845]	validation-rmse:6.41501
# [846]	validation-rmse:6.41496
# [847]	validation-rmse:6.41497
# [848]	validation-rmse:6.41485
# [849]	validation-rmse:6.41489
# [850]	validation-rmse:6.41484
# [851]	validation-rmse:6.41479
# [852]	validation-rmse:6.41472
# [853]	validation-rmse:6.41468
# [854]	validation-rmse:6.41466
# [855]	validation-rmse:6.41453
# [856]	validation-rmse:6.41448
# [857]	validation-rmse:6.41441
# [858]	validation-rmse:6.41447
# [859]	validation-rmse:6.41433
# [860]	validation-rmse:6.41436
# [861]	validation-rmse:6.41432
# [862]	validation-rmse:6.41436
# [863]	validation-rmse:6.41434
# [864]	validation-rmse:6.41429
# [865]	validation-rmse:6.41421
# ...
# [87]	validation-rmse:6.61576
# [88]	validation-rmse:6.61554
# [89]	validation-rmse:6.61531
# [90]	validation-rmse:6.61517
# [91]	validation-rmse:6.61471
# [92]	validation-rmse:6.61445
# [93]	validation-rmse:6.61416
# [94]	validation-rmse:6.61404
# [95]	validation-rmse:6.61379
# [96]	validation-rmse:6.61369
# [97]	validation-rmse:6.61343
# [98]	validation-rmse:6.61319
# [99]	validation-rmse:6.61284
# [100]	validation-rmse:6.61277
# [101]	validation-rmse:6.61231
# [102]	validation-rmse:6.61215
# [103]	validation-rmse:6.61200
# [104]	validation-rmse:6.61176
# [105]	validation-rmse:6.61160
# [106]	validation-rmse:6.61112
# [107]	validation-rmse:6.61107
# [108]	validation-rmse:6.61060
# [109]	validation-rmse:6.61037
# [110]	validation-rmse:6.61005
# [111]	validation-rmse:6.61008
# [112]	validation-rmse:6.60998
# [113]	validation-rmse:6.61004
# [114]	validation-rmse:6.60989
# [115]	validation-rmse:6.60952
# [116]	validation-rmse:6.60954
# [117]	validation-rmse:6.60908
# [118]	validation-rmse:6.60906
# [119]	validation-rmse:6.60893
# [120]	validation-rmse:6.60891
# [121]	validation-rmse:6.60858
# [122]	validation-rmse:6.60852
# [123]	validation-rmse:6.60837
# [124]	validation-rmse:6.60815
# [125]	validation-rmse:6.60812
# [126]	validation-rmse:6.60797
# [127]	validation-rmse:6.60788
# [128]	validation-rmse:6.60761
# [129]	validation-rmse:6.60768
# [130]	validation-rmse:6.60757
# [131]	validation-rmse:6.60745
# [132]	validation-rmse:6.60737
# [133]	validation-rmse:6.60729
# [134]	validation-rmse:6.60709
# [135]	validation-rmse:6.60704
# [136]	validation-rmse:6.60692
# [137]	validation-rmse:6.60673
# [138]	validation-rmse:6.60639
# [139]	validation-rmse:6.60644
# [140]	validation-rmse:6.60612
# [141]	validation-rmse:6.60613
# [142]	validation-rmse:6.60607
# [143]	validation-rmse:6.60595
# [144]	validation-rmse:6.60582
# [145]	validation-rmse:6.60574
# [146]	validation-rmse:6.60561
# [147]	validation-rmse:6.60568
# [148]	validation-rmse:6.60543
# [149]	validation-rmse:6.60529
# [150]	validation-rmse:6.60521
# [151]	validation-rmse:6.60512
# [152]	validation-rmse:6.60503
# [153]	validation-rmse:6.60487
# [154]	validation-rmse:6.60471
# [155]	validation-rmse:6.60476
# [156]	validation-rmse:6.60459
# [157]	validation-rmse:6.60463
# [158]	validation-rmse:6.60425
# [159]	validation-rmse:6.60434
# [160]	validation-rmse:6.60424
# [161]	validation-rmse:6.60415
# [162]	validation-rmse:6.60409
# [163]	validation-rmse:6.60389
# [164]	validation-rmse:6.60369
# [165]	validation-rmse:6.60366
# [166]	validation-rmse:6.60337
# [167]	validation-rmse:6.60338
# [168]	validation-rmse:6.60318
# [169]	validation-rmse:6.60324
# [170]	validation-rmse:6.60306
# [171]	validation-rmse:6.60309
# [172]	validation-rmse:6.60283
# [173]	validation-rmse:6.60291
# [174]	validation-rmse:6.60263
# [175]	validation-rmse:6.60262
# [176]	validation-rmse:6.60237
# [177]	validation-rmse:6.60240
# [178]	validation-rmse:6.60233
# [179]	validation-rmse:6.60233
# [180]	validation-rmse:6.60232
# [181]	validation-rmse:6.60216
# [182]	validation-rmse:6.60217
# [183]	validation-rmse:6.60222
# [184]	validation-rmse:6.60209
# [185]	validation-rmse:6.60197
# [186]	validation-rmse:6.60185
# [187]	validation-rmse:6.60180
# [188]	validation-rmse:6.60169
# [189]	validation-rmse:6.60151
# [190]	validation-rmse:6.60149
# [191]	validation-rmse:6.60132
# [192]	validation-rmse:6.60134
# [193]	validation-rmse:6.60122
# [194]	validation-rmse:6.60121
# [195]	validation-rmse:6.60118
# [196]	validation-rmse:6.60113
# [197]	validation-rmse:6.60104
# [198]	validation-rmse:6.60098
# [199]	validation-rmse:6.60072
# [200]	validation-rmse:6.60078
# [201]	validation-rmse:6.60045
# [202]	validation-rmse:6.60043
# [203]	validation-rmse:6.60025
# [204]	validation-rmse:6.60029
# [205]	validation-rmse:6.60026
# [206]	validation-rmse:6.60027
# [207]	validation-rmse:6.60027
# [208]	validation-rmse:6.60013
# [209]	validation-rmse:6.60015
# [210]	validation-rmse:6.60005
# [211]	validation-rmse:6.60010
# [212]	validation-rmse:6.59995
# [213]	validation-rmse:6.59994
# [214]	validation-rmse:6.59998
# [215]	validation-rmse:6.59985
# [216]	validation-rmse:6.59984
# [217]	validation-rmse:6.59973
# [218]	validation-rmse:6.59966
# [219]	validation-rmse:6.59949
# [220]	validation-rmse:6.59944
# [221]	validation-rmse:6.59926
# [222]	validation-rmse:6.59907
# [223]	validation-rmse:6.59898
# [224]	validation-rmse:6.59898
# [225]	validation-rmse:6.59901
# [226]	validation-rmse:6.59905
# [227]	validation-rmse:6.59890
# [228]	validation-rmse:6.59888
# [229]	validation-rmse:6.59883
# [230]	validation-rmse:6.59863
# [231]	validation-rmse:6.59858
# [232]	validation-rmse:6.59836
# [233]	validation-rmse:6.59842
# [234]	validation-rmse:6.59838
# [235]	validation-rmse:6.59803
# [236]	validation-rmse:6.59812
# [237]	validation-rmse:6.59824
# [238]	validation-rmse:6.59801
# [239]	validation-rmse:6.59795
# [240]	validation-rmse:6.59775
# [241]	validation-rmse:6.59779
# [242]	validation-rmse:6.59768
# [243]	validation-rmse:6.59766
# [244]	validation-rmse:6.59757
# [245]	validation-rmse:6.59753
# [246]	validation-rmse:6.59731
# [247]	validation-rmse:6.59733
# [248]	validation-rmse:6.59740
# [249]	validation-rmse:6.59722
# [250]	validation-rmse:6.59724
# [251]	validation-rmse:6.59710
# [252]	validation-rmse:6.59711
# [253]	validation-rmse:6.59704
# [254]	validation-rmse:6.59703
# [255]	validation-rmse:6.59719
# [256]	validation-rmse:6.59711
# [257]	validation-rmse:6.59713
# [258]	validation-rmse:6.59709
# [259]	validation-rmse:6.59689
# [260]	validation-rmse:6.59671
# [261]	validation-rmse:6.59681
# [262]	validation-rmse:6.59678
# [263]	validation-rmse:6.59639
# [264]	validation-rmse:6.59640
# [265]	validation-rmse:6.59640
# [266]	validation-rmse:6.59628
# [267]	validation-rmse:6.59627
# [268]	validation-rmse:6.59618
# [269]	validation-rmse:6.59621
# [270]	validation-rmse:6.59614
# [271]	validation-rmse:6.59604
# [272]	validation-rmse:6.59605
# [273]	validation-rmse:6.59604
# [274]	validation-rmse:6.59602
# [275]	validation-rmse:6.59583
# [276]	validation-rmse:6.59595
# [277]	validation-rmse:6.59586
# [278]	validation-rmse:6.59557
# [279]	validation-rmse:6.59552
# [280]	validation-rmse:6.59554
#   4%|▍         | 2/50 [14:59<4:58:07, 372.66s/trial, best loss: 6.40207655216118]

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db") 
experiments = mlflow.search_experiments()
for exp in experiments:
    print(f"ID: {exp.experiment_id}, Name: {exp.name}")
# Out:
# ID: 1, Name: nyc-taxi-experiment
# ID: 0, Name: Default

# %%
dv = DictVectorizer()
df_train['PU_DO'] = df_train["PULocationID"] + df_train["DOLocationID"]
df_val['PU_DO'] = df_val["PULocationID"] + df_val["DOLocationID"]
categorical = ["PU_DO"]
numerical = ["trip_distance"]

train_dicts = df_train[categorical + numerical].to_dict(orient="records")
x_train = dv.fit_transform(train_dicts)
val_dicts = df_val[categorical + numerical].to_dict(orient="records")
x_val = dv.transform(val_dicts)

# %%
target = "duration"
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_val)
mse = mean_squared_error(y_val, y_pred)

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(7.787351949801436)

# %%
# Out:
# np.float64(9.240687964649634)
